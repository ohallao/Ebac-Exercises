# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %matplotlib notebook

# %%
path = r"/content/b1abb33c4f.csv"
sinasc = pd.read_csv(path)
print(sinasc.shape)
# Out:
# (27028, 69)

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
plt.close('all')
plt.rc('figure', figsize=(12, 10))
fig, axes = plt.subplots(3, 2)
axes[2,1].set_axis_off()
ax.tick_params(axis='x', rotation=90)

sns.countplot(ax = axes[0, 0], x='APGAR1', data=sinasc)
sns.countplot(ax = axes[0, 1], x='APGAR5', data=sinasc)
sns.countplot(ax = axes[1, 0], x='SEXO', data=sinasc)
my_plot = sns.countplot(ax = axes[1, 1], x='GESTACAO', data=sinasc)
sns.countplot(ax = axes[2, 0], x='ESTCIVMAE', data=sinasc)

my_plot.set_xticklabels(my_plot.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, '37 a 41 semanas'),
#  Text(1, 0, '42 semanas e mais'),
#  Text(2, 0, '32 a 36 semanas'),
#  Text(3, 0, '22 a 27 semanas'),
#  Text(4, 0, '28 a 31 semanas'),
#  Text(5, 0, 'Menos de 22 semanas')]

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
media_apgar5 = sinasc.groupby('CONSULTAS')['APGAR5'].mean()
plt.bar(media_apgar5.index, media_apgar5.values)
plt.xlabel('Consultas')
plt.ylabel('APGAR5 Médio')
# Out:
# Text(0, 0.5, 'APGAR5 Médio')

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %%
plt.close('all')
plt.rc('figure', figsize=(10, 10))
fig, axes = plt.subplots(2, 2)
fig.subplots_adjust(hspace=0.5)

sns.countplot(ax=axes[0, 0], x='SEXO', data=sinasc)
axes[0, 0].set_xlabel('Sexo')
my_plot=sns.countplot(ax=axes[0, 1], x='GESTACAO', data=sinasc)
axes[0, 0].set_xlabel('Gestação')
my_plot.set_xticklabels(my_plot.get_xticklabels(), rotation=45)
sns.countplot(ax=axes[1, 0], x='ESTCIVMAE', data=sinasc)
axes[0, 0].set_xlabel('Estado Civil Mãeo')
sns.countplot(ax=axes[1, 1], x='CONSULTAS', data=sinasc)
axes[0, 0].set_xlabel('Consultas')
# Out:
# Text(0.5, 0, 'Consultas')
